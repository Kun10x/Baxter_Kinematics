# %%
# !nvidia-smi
# Out:
# Sun Apr 30 15:01:54 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   59C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 562.2/562.2 kB 37.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.7/201.7 kB 26.6 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.90 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.4/78.2 GB disk)

# %%
from ultralytics import YOLO
from IPython.display import display, Image

# %%
# %cd /content/drive/MyDrive
# !yolo task=detect mode=train model=yolov8s.pt data= data.yaml epochs=200 imgsz=640 plots=True
# Out:
# /content/drive/MyDrive
# Ultralytics YOLOv8.0.90 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/runs/detect/train11/weights/best.pt conf=0.25 source=data/val/images
# Out:
# Ultralytics YOLOv8.0.90 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126745 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/18 /content/drive/MyDrive/data/val/images/image_14.jpg: 416x640 1 chessboard, 11 whites, 12 blacks, 63.2ms
# image 2/18 /content/drive/MyDrive/data/val/images/image_400.jpg: 416x640 1 chessboard, 12 whites, 12 blacks, 12.7ms
# image 3/18 /content/drive/MyDrive/data/val/images/image_401.jpg: 416x640 1 chessboard, 12 whites, 12 blacks, 12.7ms
# image 4/18 /content/drive/MyDrive/data/val/images/image_402.jpg: 416x640 1 chessboard, 12 whites, 12 blacks, 12.6ms
# image 5/18 /content/drive/MyDrive/data/val/images/image_403.jpg: 416x640 1 chessboard, 12 whites, 12 blacks, 12.7ms
# image 6/18 /content/drive/MyDrive/data/val/images/image_404.jpg: 416x640 1 chessboard, 11 whites, 12 blacks, 12.7ms
# image 7/18 /content/drive/MyDrive/data/val/images/image_405.jpg: 416x640 1 chessboard, 11 whites, 12 blacks, 12.7ms
# ...
